# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset_original = pd.read_csv("datasets/CASHPOINT_ID_4.csv")
dataset_synthetic = pd.read_csv("datasets/CASHPOINT_ID_4_GENERATED.csv")

# %%
def get_distribution(df):
    out = df.QT_OUT_20.to_numpy()
    rec = df.QT_RECYCLED_20.to_numpy()
    return out+rec

# %%
plt.plot(dataset_original.QT_OUT_20 + dataset_original.QT_RECYCLED_20)
